# %%
import matplotlib.pyplot as plt, numpy as np, cv2, os, pandas as pd
import cv2
import torch
import numpy as np

device = "cuda" if torch.cuda.is_available() else "cpu"

# Load image
base_path= "../data"
img_path = f"{base_path}/10140238/10140238-0001.png"

# Convert to HSV for red mask
img_bgr = cv2.imread(img_path, cv2.IMREAD_COLOR)

# %%
from PIL import Image
import cv2

im_pil = Image.fromarray(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
im_pil.show()

# %%
from Physionet_ECG_challenge.src.utils import *
im_no_red=remove_red_grid(img_bgr)
# Out:
# Removing red grid from image...

# %%
im_pil = Image.fromarray(cv2.cvtColor(im_no_red, cv2.COLOR_BGR2RGB))
im_pil.show()

# %%
im_mask = waveform_binary_mask(im_no_red)

Image.fromarray(cv2.cvtColor(im_mask, cv2.COLOR_BGR2RGB)).show()
# Out:
# Removing red grid from image...
